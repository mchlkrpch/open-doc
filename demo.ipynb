# %% [markdown]
# # Open-doc QA датасет

# %%
from oqa import OpenDocQA
od = OpenDocQA()
od.df
# Out:
#        domain    set            src  \
# 0     science  metal  aluminium.pdf
# 1     science  metal  aluminium.pdf
# 2     science  metal  aluminium.pdf
# 3     science  metal  aluminium.pdf
# 4     science  metal  aluminium.pdf
# ...       ...    ...            ...
# 1004      fin     ai    trends3.pdf
# 1005      fin     ai    trends3.pdf
# 1006      fin     ai    trends3.pdf
# 1007      fin     ai    trends3.pdf
# 1008      fin     ai    trends3.pdf
#
#                                                     txt                   tp  \
# 0     4.3 Производство первичного алюминия\r\nНа алю...               Simple
# 1     4.3 Производство первичного алюминия\r\nНа алю...          With errors
# 2     4.3 Производство первичного алюминия\r\nНа алю...                Trash
# 3     4.3 Производство первичного алюминия\r\nНа алю...        Reformulation
# 4     4.3 Производство первичного алюминия\r\nНа алю...  Incorrect by design
# ...

# %%
ex = od[100]
print(f"""topic:{ex.domain}/{ex.set}
Q: {ex.q}
A: {ex.a}

use document/html: {ex.src} (dataset has source: {od.doc_pts[ex.src]})
to answer
""")
# Out:
# topic:science/oil
# Q: Какие процедуры обеспечивают безопасность устройств, разделяющих смеси на начальном этапе обработки?
# A: Регулярное техническое обслуживание и ремонт.
#
# Техническое диагностирование методами неразрушающего контроля.
#
# Проведение технического освидетельствования (осмотр раз в 2 года, гидравлические испытания – раз в 8 лет).
#
# Своевременная экспертиза промышленной безопасности (ЭПБ).
#
# Постоянный контроль параметров (уровня, давления).
#
#
#
# use document/html: industry.pdf (dataset has source: /home/vboxuser/Documents/open-doc/data/industry.pdf)
# to answer
